# %%
import os

from jupyterlab_h5web import H5Web

print(os.getcwd())
with open(f"{os.getcwd()}{os.sep}target_directory.txt") as fp:
    trg_directory = f"{fp.readline().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0 : trg_directory.rfind('/')]}"
print(prefix)

# %%
file_path = f"{prefix}{os.sep}pynxtools/163.72fd1dae5dc10ff6007bdcd8c63a5db39e9ae276c8142b97aad5091e7d410d59.msa.nxs"
H5Web(file_path)
