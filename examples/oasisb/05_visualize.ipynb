# %%
import glob
import os

import h5py
from jupyterlab_h5web import H5Web

print(os.getcwd())
with open(f"{os.getcwd()}{os.sep}target_directory.txt") as fp:
    trg_directory = f"{fp.readline().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0 : trg_directory.rfind('/')]}"
print(prefix)

# %%
file_path = "655.ab3077736b785230ece3ff2a3b8e4dde12129f953fa7cd9a83d31a1d4261a3da.dm4"
file_path = "093.6a6f369bbabf49347214c99c4fda1edcb496aa32cc112ff9fee738a2aa1cc24a.0f4c31e286a45a78ac5a9818db1a703a813f7cab08bc94fe0f536efb6056e175"
file_path = "018.328b9c6c2fd25d4e908d2b6410d867015e47a74ad08bb3ab2e0f27392878afd9"
file_path = "079.32e46c7ac07680ff9a6c2cf55875343fc9543a12617b219eb11b5a03cce516a9.image"
file_path = "116.ea5c800cb301f0504886ad124d412d95112e2931b0eee55a99bdbe3f1cc279a9.image"
file_path = "157.26beda22206e51899db16504ea5eadb7fe448ff9802aaefb5f1d1dabe0bac41d.image"
file_path = "160.325bbc1989c9ea737b68dd2e8affedcfdb593f073c2e917246ee1021e02b0020.d1734cae7dd95ab9096d93f403d8d4afab157c939380cd7b6ca22fdae5298dce.image"
H5Web(f"{prefix}{os.sep}pynxtools{os.sep}{file_path}.nxs")
