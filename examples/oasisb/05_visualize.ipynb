# %%
import os

from jupyterlab_h5web import H5Web

print(os.getcwd())
with open(f"{os.getcwd()}{os.sep}target_directory.txt") as fp:
    trg_directory = f"{fp.readline().strip().replace('/', os.sep)}"
prefix = f"{trg_directory[0 : trg_directory.rfind('/')]}"
print(prefix)

# %%
file_path = "163.72fd1dae5dc10ff6007bdcd8c63a5db39e9ae276c8142b97aad5091e7d410d59.msa"
file_path = "049.dfe2df4cd6cc3fbb9632b2d95fe9259a2a302eb3a92e023968d5f46c699ccc6e.emd"
file_path = "049.93a9f8eaf6abf50d766b7d2a0c1b19e7818fadac02c07967aeecc395b2822c59.emd"
file_path = "063.bab0802c06b994125240e88fe71a452567015200a4ba61078d6fd4a4bfa216a4.dm3"
file_path = "361.de912e587221f9b023606d53bd7b94d70c62b2a8100aee826466f436de9b5343.dm4"
file_path = "303.d77ad89fd42485c0b528a9535780a25bf8d2d3168a3bd232f1f197cc56bc2f55.emd"
H5Web(f"{prefix}{os.sep}pynxtools{os.sep}{file_path}.nxs")
