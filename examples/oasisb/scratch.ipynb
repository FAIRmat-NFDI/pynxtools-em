# %%
# rename and moving files around
import os

from pynxtools_em.examples.oasisb_utils import get_project_id

print(os.getcwd())
with open("source_directory.txt") as fp:
    src_directory = f"{fp.readline().strip().replace('/', os.sep)}"
print(src_directory)

# %%
file_paths = [
    "organize_in/zenodo/4058145",
    "organize_in/zenodo/4580546",
    "organize_in/zenodo/7014406",
    "organize_in/zenodo/8041868",
    "organize_in/zenodo/10572840",
    "organize_in/zenodo/14966093",
    "organize_in/zenodo/15124437",
    "organize_in/zenodo/15192783",
    "organize_in/zenodo/15201029",
    "organize_in/zenodo/15340519",
    "organize_in/zenodo/15342907",
    "organize_in/zenodo/15490069",
    "organize_in/zenodo/15598483",
    "organize_in/zenodo/15676408",
    "organize_in/zenodo/15729695",
    "organize_in/zenodo/15778499",
    "organize_in/zenodo/15789295",
    "organize_in/zenodo/16633511",
    "organize_in/zenodo/16736945",
    "organize_in/zenodo/16803752",
    "organize_in/zenodo/16884823",
    "organize_in/zenodo/16913254",
    "organize_in/zenodo/16983773",
    "organize_in/zenodo/17034117",
    "organize_in/zenodo/17037765",
    "organize_in/zenodo/17085695",
    "organize_in/zenodo/17106852",
    "organize_in/zenodo/17158369",
    "organize_in/zenodo/17243847",
    "organize_in/zenodo/17288543",
    "organize_in/zenodo/17338078",
    "organize_in/zenodo/17358227",
    "organize_in/zenodo/17522856",
    "organize_in/zenodo/17905368",
    "organize_in/zenodo/17944277",
    "organize_in/zenodo/17944281",
    "organize_in/zenodo/17944289",
    "organize_in/zenodo/17944314",
    "organize_in/zenodo/17944318",
    "organize_in/zenodo/17944325",
    "organize_in/zenodo/17944329",
    "organize_in/zenodo/17944334",
    "organize_in/zenodo/17944341",
    "organize_in/zenodo/17944346",
    "organize_in/zenodo/17944348",
    "organize_in/zenodo/17944354",
    "organize_in/zenodo/17944356",
    "organize_in/zenodo/17944360",
    "organize_in/zenodo/17944366",
    "organize_in/zenodo/17944368",
    "organize_in/zenodo/17944374",
    "organize_in/zenodo/17944382",
    "organize_in/zenodo/17944384",
    "organize_in/zenodo/17944392",
    "organize_in/zenodo/17944394",
    "organize_in/zenodo/17944414",
    "organize_in/zenodo/17944427",
    "organize_in/zenodo/17944472",
    "organize_in/zenodo/17944478",
    "organize_in/zenodo/17944483",
    "organize_in/zenodo/17944489",
    "organize_in/zenodo/17944496",
    "organize_in/zenodo/17944501",
    "organize_in/zenodo/17944503",
    "organize_in/zenodo/17944508",
    "organize_in/zenodo/17944513",
    "organize_in/zenodo/17944516",
    "organize_in/zenodo/17944526",
    "organize_in/zenodo/17944533",
    "organize_in/zenodo/17944539",
    "organize_in/zenodo/17944545",
    "organize_in/zenodo/17944549",
    "organize_in/zenodo/17944551",
    "organize_in/zenodo/17944553",
    "organize_in/zenodo/17944556",
    "organize_in/zenodo/17944561",
    "organize_in/zenodo/17944566",
    "organize_in/zenodo/17944570",
    "organize_in/zenodo/17944579",
    "organize_in/zenodo/17944584",
    "organize_in/zenodo/17944588",
    "organize_in/zenodo/17944596",
    "organize_in/zenodo/17944607",
    "organize_in/zenodo/17478083.zip",
    "organize_in/zenodo/17512156.zip",
    "organize_in/zenodo/17576831.zip",
    "organize_in/zenodo/17748462.zip",
    "organize_in/zenodo/18557610.zip",
    "organize_in/zenodo/18668585.zip",
    "organize_in/zenodo/18878199.zip",
    "organize_in/zenodo/19050106.zip",
    "organize_in/zenodo/19217212.zip",
    "organize_in/zenodo/19290357.zip",
    "organize_in/zenodo/19334962.zip",
    "organize_in/zenodo/19472978.zip",
    # "organize_in/zenodo/28255244.zip"  # not a zenodo dataset
]
print(len(file_paths))

mapping: dict[str, int] = {}

bibtex: list[str] = []
idx = 634
# toggle = 15
# toggle_max = 15
for jdx, file_path in enumerate(file_paths):
    # if jdx < toggle:
    #     continue
    assume_zenodo = file_path[file_path.rfind("/") + 1 :].replace(".zip", "")
    print(f"{jdx}, {file_path}, {assume_zenodo}")
    bibtex.append(f"@Misc{{D{get_project_id(f'{idx + jdx}')},")
    bibtex.append(f"doi={{10.5281/zenodo.{assume_zenodo}}},")
    bibtex.append(f"}}")
    mapping[f"{src_directory}{os.sep}{file_path}"] = idx + jdx
    # webbrowser.open_new_tab(f"https://www.zenodo.org/records/{assume_zenodo}")
    # idx += 1
    # toggle += 1
    # if jdx > toggle + toggle_max:
    #     break
    #     toggle = 0
    # if idx > 800 + toggle_max:
    #     break
for line in bibtex:
    print(line)
for key, value in mapping.items():
    print(f"{key}, {value}")

# %%
# find empty and missing directories
for idx in range(1, 815):
    path = f"{src_directory}{os.sep}{get_project_id(f'{idx}')}"
    if not os.path.isdir(path):
        print(f"{path} directory missing!")
        continue
    if not os.listdir(path):
        print(f"{path} exists but has no content!")

# %%
# find zenodo zip archives which have in the meantime been unpacked
for file_path in file_paths:
    if file_path.endswith(".zip"):
        if not os.path.isfile(f"{src_directory}{os.sep}{file_path}"):
            print(f"File {file_path} has an issue")
    else:
        if not os.path.isdir(f"{src_directory}{os.sep}{file_path}"):
            print(f"Dir {file_path} has an issue")

# %%
# move zenodo
import os
import shutil

for jdx, file_path in enumerate(file_paths):
    if jdx < 2:
        continue
    zenodo = file_path[file_path.rfind("/") + 1 :].replace(".zip", "")
    print(f"{idx + jdx}, {file_path}, {zenodo}")
    target_path = f"{src_directory}{os.sep}{get_project_id(f'{idx + jdx}')}"
    source_path = f"{src_directory}{os.sep}{file_path}"
    print(f"{source_path}\n{target_path}")
    os.makedirs(target_path, exist_ok=True)
    shutil.move(source_path, target_path)
    print("moved")
    # break

# %%
## Find compression nests

# %%
# ignore
import webbrowser

import bibtexparser

from pynxtools_em.examples.oasisb_bibliography import get_bibliographical_metadata

with open(f"{src_directory}{os.sep}aaa_legacy_data.bib") as fp:
    bib = bibtexparser.load(fp).entries_dict
for project_name in range(531, 552):
    project_id = get_project_id(f"{project_name}")
    data_and_paper = get_bibliographical_metadata(bib, project_id)
    webbrowser.open_new_tab(f"https://doi.org/{bib[data_and_paper[0]]['doi']}")
    # print(data_and_paper)

# %%
# fix issues with seven zip files
import pandas as pd

spread_sheet_of_all_projects = pd.read_excel(
    f"{src_directory}{os.sep}aaa_legacy_data.ods",
    sheet_name="aaa_legacy_data",
    engine="odf",
    dtype=str,
).fillna("")

for idx, row in enumerate(spread_sheet_of_all_projects.itertuples(index=True)):
    if row.parse in ["1", "2"]:  # "1",
        project_id = get_project_id(row.project_name)
        log_file_name = f"{src_directory}{os.sep}{project_id}.sha256.issues.csv"
        if os.path.isfile(log_file_name):
            if os.path.getsize(log_file_name) > 426:
                print(f"{project_id}")
        else:
            print(f"{project_id}, no logfile!")

# %%
# print(os.path.getsize(f"{src_directory}{os.sep}472.sha256.issues.csv"))

# %%
organize_in = [
    "15824211",
    "18022824",
    "19930489",
    "20020671",
    "20085570",
    "20128369",
    "20175741",
    "20290635",
    "20331737",
    "20376379",
    "20376534",
    "20376828",
    "20376903",
]
organize_in = [
    "10.18122/B2QX4Z",  # 3_dpa_Fe_9Cr_ODS.zip
    "10.18122/B2VM5G",  # AR_Fe_9Cr_ODS_20170929T225806Z_001.zip
    "10.18122/B20K5C",  # Fe_9_Cr_ODS__As_received__TEM_Images.zip
    "10.18122/B2R30G",  # Fe_9_Cr_ODS__Fe2__irradiated_to_1_dpa_at_500C__TEM_Images.zip
    "10.18122/B2GK5Q",  # Fe_9_Cr_ODS__Fe2__irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B2730T",  # Fe_9_Cr_ODS__Fe2__irradiated_to_50_dpa_at_400C__TEM_Images.zip
    "10.18122/B2ZK52",  # Fe_9_Cr_ODS__Fe2__irradiated_to_100_dpa_at_500C__TEM_Images.zip
    "10.18122/B2FK5D",  # Fe_9_Cr_ODS__Proton_irradiated_to_1_dpa_at_500C__TEM_Images.zip
    "10.18122/B2630H",  # Fe_9_Cr_ODS__Proton_irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B2XK5R",  # Fe_9_Cr_ODS__Proton_irradiated_to_7_dpa_at_500C__TEM_Images.zip
    "10.18122/B2P30V",  # HCM12A__Fe2__irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B2DK53",  # HCM12A__Fe2__irradiated_to_100_dpa_at_500C__TEM_Images.zip
    "10.18122/B25306",  # HCM12A__Neutron_irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B2WK5F",  # HCM12A__Proton_irradiated_to_1_dpa_at_500C__TEM_Images.zip
    "10.18122/B2N30J",  # HCM12A__Proton_irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B2CP4F",  # HT9__Fe2__irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B24590",  # HT9__Fe2__irradiated_to_100_dpa_at_500C__TEM_Images.zip
    "10.18122/B2VP4S",  # HT9__Neutron_irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B2M59B",  # HT9__Proton_irradiated_to_1_dpa_at_500C__TEM_Images.zip
    "10.18122/B2BP44",  # HT9__Proton_irradiated_to_3_dpa_at_500C__TEM_Images.zip
    "10.18122/B2M41Z",  # 100_dpa_Fe_9Cr_ODS_20170929T234843Z_001
]
import webbrowser

offset = 851
csv = []
for idx, entry in enumerate(organize_in):
    # webbrowser.open_new_tab(f"https://zenodo.org/records/{entry}")
    csv.append(f"@Misc{{D{offset + idx},")
    csv.append(f"doi = {{{entry}}},")  # {{10.5281/zenodo.{entry}}},")
    csv.append(f"}}\n")
for entry in csv:
    print(entry)

# %%
import os

for idx in range(852, 871 + 1):
    os.mkdir(f"organize_in/boise_state/{idx}")

# %% [markdown]
# ## Assure that we have for each dataset copyright information and assure that it matches with those from OpenAlex

# %%
# https://spdx.org/licenses
# https://developers.openalex.org
# build a look-up table of bib keys
import webbrowser
from json import JSONDecodeError

for row in spread_sheet_of_all_projects.itertuples(index=True):
    # if row.parse in (1, 2):  # get cross-ref data if available if dataset is CC0 or CC-BY-4.0
    if int(row.project_name) < 1:  # skip all before
        continue
    if int(row.project_name) > 822:  # skip all after
        continue
    if row.license != "":
        continue
    project_id = get_project_id(f"{row.project_name}")
    match = []
    token = f"D{project_id}"
    for key in bib:
        if not key.startswith(token):
            continue
        if key not in match:
            match = [key]
        else:
            print(f"ERROR::Multiple matching D{project_id}* keys")
    if len(match) != 1:
        pass
        # print(f"ERROR::D{project_id}* not found")
    else:
        # print(f"{project_id}, {match[0]}")
        if "doi" in bib[match[0]]:
            doi = bib[match[0]]["doi"]
            webbrowser.open_new_tab(f"https://doi.org/{doi}")
            continue
            if doi.startswith("10.5281"):
                url = f"https://zenodo.org/api/records/{doi.replace('10.5281/zenodo.', '')}"
                try:
                    data = requests.get(url, timeout=30).json()
                    print(
                        f"{project_id}, {match[0]}, {doi}, {data['metadata']['license']['id']}"
                    )
                    del data
                except (JSONDecodeError, KeyError):
                    pass
                # time.sleep(1.0)
                # Zenodo anonymous API access rate limit 60/min, currently code though is slower than 1s per project
                del url
        else:
            pass
            # print(f"{project_id}, no DOI")
    del project_id, match, token
    continue

    if row.license not in ("CC BY 4.0", "CC0 1.0", "CC BY 4.0 / CC0 1.0"):
        pass
        # search matching reference from bib, take advantage that each reference always either startswith
        # f"D{project_id}" (dataset) or f"A{project_id}" (associated key paper)

# %%
json_files = set()
for root, dirs, files in os.walk("openalex"):
    for file in files:
        # fpath = f"{root}/{file}".replace(os.sep * 2, os.sep)
        json_files.add(file)
print(len(json_files))

# %%
mdata = fd.FlatDict(data, delimiter="/")
for key, obj in mdata.items():
    print(f"{key}, {obj}")

# %%
authorships = data.get("authorships", [])
if len(authorships) == 0:
    print("No authorships")

first_author = authorships[0]

institutions = first_author.get("institutions", [])
if not institutions:
    print("No institutions")

first_institution = institutions[0]

result = {
    "doi": doi,
    "first_author": first_author.get("author", {}).get("display_name"),
    "institution": first_institution.get("display_name"),
    "country_code_iso3": first_institution.get("country_code"),
    "town": first_institution.get("city"),
}
print(result)

# %%
# db = BibDatabase()
# db.entries = [new_bib]
# with open(
#     f"{src_directory}{os.sep}aaa_legacy_bib_mod.bib", "w", encoding="utf-8"
# ) as bibfile:
#     bibfile.write(writer.write(db))
